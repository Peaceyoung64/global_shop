# %%
# %sql
CREATE OR REPLACE TABLE workspace.bronze.customers
USING DELTA
AS
SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_table/customers.csv',
  format => 'csv',
  header => true
);

# %%
# %sql

CREATE OR REPLACE TABLE workspace.bronze.products
USING DELTA
AS

SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_table/products.csv',
  format => 'csv',
  header => true
);

# %%
# %sql

CREATE OR REPLACE TABLE workspace.bronze.sales
USING DELTA
AS

SELECT *
FROM read_files(
  '/Volumes/workspace/bronze/source_table/sales.csv',
  format => 'csv',
  header => true
);
